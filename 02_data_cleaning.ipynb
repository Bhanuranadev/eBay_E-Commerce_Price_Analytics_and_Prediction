# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/raw_data.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (250, 6)
#                                                title   price currency  \
# 0  ACEMAGIC RX16 16" Gaming Laptop AMD Ryzen 7 68...  459.00      USD
# 1  [90% new]ACEMAGIC AX17 UHD Laptop 17.3" FHD Ne...  229.99      USD
# 2  HP Envy 13.3" FHD Laptop 4-Core i5-1135G7 up t...  379.99      USD
# 3  LENOVO 20L6S2DR00-Intel(R) Core(TM) i5-8350U C...  100.10      USD
# 4  Lenovo - Yoga 7 2-in-1 - Copilot+ PC - 14" 2K ...  799.99      USD
#
#                 category condition  \
# 0  PC Laptops & Netbooks       New
# 1  PC Laptops & Netbooks      Used
# 2  PC Laptops & Netbooks      Used
# 3  PC Laptops & Netbooks      Used
# 4  PC Laptops & Netbooks       New
#
#                                             item_url
# 0  https://cgi.sandbox.ebay.com/ACEMAGIC-RX16-16-...
# 1  https://cgi.sandbox.ebay.com/90-new-ACEMAGIC-A...
# 2  https://cgi.sandbox.ebay.com/HP-Envy-13-3-FHD-...
# 3  https://cgi.sandbox.ebay.com/LENOVO-20L6S2DR00...
# 4  https://cgi.sandbox.ebay.com/Lenovo-Yoga-7-2-i...

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      250 non-null    object
#  1   price      250 non-null    float64
#  2   currency   250 non-null    object
#  3   category   250 non-null    object
#  4   condition  250 non-null    object
#  5   item_url   250 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 11.8+ KB
# title        0
# price        0
# currency     0
# category     0
# condition    0
# item_url     0
# dtype: int64

# %%
df["price"] = pd.to_numeric(df["price"], errors="coerce")

# %%
# Drop rows with missing price (target variable)
df = df.dropna(subset=["price"])

# Fill missing categorical values
df["category"].fillna("Unknown", inplace=True)
df["condition"].fillna("Unknown", inplace=True)
df["currency"].fillna("Unknown", inplace=True)

print("After cleaning shape:", df.shape)
df.head()
# Out:
# After cleaning shape: (250, 6)
# C:\Users\ranab\AppData\Local\Temp\ipykernel_30352\99357423.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["category"].fillna("Unknown", inplace=True)
# C:\Users\ranab\AppData\Local\Temp\ipykernel_30352\99357423.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["condition"].fillna("Unknown", inplace=True)
# C:\Users\ranab\AppData\Local\Temp\ipykernel_30352\99357423.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["currency"].fillna("Unknown", inplace=True)
#                                                title   price currency  \
# 0  ACEMAGIC RX16 16" Gaming Laptop AMD Ryzen 7 68...  459.00      USD
# 1  [90% new]ACEMAGIC AX17 UHD Laptop 17.3" FHD Ne...  229.99      USD
# 2  HP Envy 13.3" FHD Laptop 4-Core i5-1135G7 up t...  379.99      USD
# 3  LENOVO 20L6S2DR00-Intel(R) Core(TM) i5-8350U C...  100.10      USD
# 4  Lenovo - Yoga 7 2-in-1 - Copilot+ PC - 14" 2K ...  799.99      USD
#
#                 category condition  \
# 0  PC Laptops & Netbooks       New
# 1  PC Laptops & Netbooks      Used
# 2  PC Laptops & Netbooks      Used
# 3  PC Laptops & Netbooks      Used
# 4  PC Laptops & Netbooks       New
#
#                                             item_url
# 0  https://cgi.sandbox.ebay.com/ACEMAGIC-RX16-16-...
# 1  https://cgi.sandbox.ebay.com/90-new-ACEMAGIC-A...
# 2  https://cgi.sandbox.ebay.com/HP-Envy-13-3-FHD-...
# 3  https://cgi.sandbox.ebay.com/LENOVO-20L6S2DR00...
# 4  https://cgi.sandbox.ebay.com/Lenovo-Yoga-7-2-i...

# %%
df = df.drop_duplicates()
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (250, 6)

# %%
cleaned_df = df[
    ["title", "price", "currency", "category", "condition"]
]

# %%
cleaned_df.to_csv("../data/cleaned_data.csv", index=False)
print(" Cleaned data saved as data/cleaned_data.csv")
# Out:
#  Cleaned data saved as data/cleaned_data.csv
